# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests
import sys
# Import the API key.
sys.path.append("../")
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_decription = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather['weather'][0]['description']
                                                                                    
                         })
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chapais
# Processing Record 2 of Set 1 | san juan
# Processing Record 3 of Set 1 | wangqing
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | tres picos
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | hauterive
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | tazovskiy
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | general roca
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | malvern
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | ishigaki
# Processing Record 30 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | parras
# City not found. Skipping...
# Processing Record 33 of Set 1 | west bay
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | port macquarie
# Processing Record 36 of Set 1 | luderitz
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | goderich
# Processing Record 39 of Set 1 | takeo
# Processing Record 40 of Set 1 | korla
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | axim
# Processing Record 44 of Set 1 | zamhlay
# City not found. Skipping...
# Processing Record 45 of Set 1 | zalesovo
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | leshukonskoye
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | jalu
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | leiyang
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | evensk
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | sibolga
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 2 | nishihara
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | sola
# Processing Record 19 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 2 | ayan
# Processing Record 21 of Set 2 | dandong
# Processing Record 22 of Set 2 | zinder
# Processing Record 23 of Set 2 | karratha
# Processing Record 24 of Set 2 | taltal
# Processing Record 25 of Set 2 | mathathane
# Processing Record 26 of Set 2 | uinskoye
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | vaja
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | port-cartier
# Processing Record 31 of Set 2 | znamenskoye
# Processing Record 32 of Set 2 | kirakira
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | lekoni
# Processing Record 35 of Set 2 | namatanai
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | havre
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | margate
# Processing Record 43 of Set 2 | porangatu
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | soyo
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | candolim
# Processing Record 48 of Set 2 | presidencia roque saenz pena
# Processing Record 49 of Set 2 | casa nova
# Processing Record 50 of Set 2 | riyadh
# Processing Record 1 of Set 3 | majene
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | mehamn
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | poum
# Processing Record 6 of Set 3 | kontagora
# Processing Record 7 of Set 3 | turayf
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | kenitra
# Processing Record 10 of Set 3 | sorocaba
# Processing Record 11 of Set 3 | chapulhuacan
# Processing Record 12 of Set 3 | alofi
# Processing Record 13 of Set 3 | tevaitoa
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | kloulklubed
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | tandil
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | broken hill
# Processing Record 22 of Set 3 | pasni
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | tocopilla
# Processing Record 25 of Set 3 | moga
# Processing Record 26 of Set 3 | domoni
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | ancud
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | erzin
# Processing Record 31 of Set 3 | banda aceh
# Processing Record 32 of Set 3 | litovko
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | jamame
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | santo amaro da imperatriz
# Processing Record 38 of Set 3 | pinawa
# Processing Record 39 of Set 3 | sioux lookout
# Processing Record 40 of Set 3 | nemuro
# Processing Record 41 of Set 3 | lokosovo
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | wickede
# Processing Record 44 of Set 3 | chara
# Processing Record 45 of Set 3 | dubbo
# Processing Record 46 of Set 3 | cervo
# Processing Record 47 of Set 3 | paranapanema
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | itarema
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | ballina
# Processing Record 5 of Set 4 | harper
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | raton
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | tiksi
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | hofn
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | hobart
# Processing Record 18 of Set 4 | omsukchan
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | licata
# Processing Record 22 of Set 4 | auki
# Processing Record 23 of Set 4 | phan thiet
# Processing Record 24 of Set 4 | marondera
# Processing Record 25 of Set 4 | dembi dolo
# Processing Record 26 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 4 | ostrovnoy
# Processing Record 28 of Set 4 | kiruna
# Processing Record 29 of Set 4 | katakwi
# Processing Record 30 of Set 4 | east london
# Processing Record 31 of Set 4 | guerrero negro
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | krasnaya gora
# Processing Record 34 of Set 4 | zanjan
# Processing Record 35 of Set 4 | santa maria
# Processing Record 36 of Set 4 | yarmouth
# Processing Record 37 of Set 4 | fort nelson
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | seymchan
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | kutum
# Processing Record 42 of Set 4 | latung
# Processing Record 43 of Set 4 | amambai
# Processing Record 44 of Set 4 | rio tuba
# Processing Record 45 of Set 4 | karaton
# Processing Record 46 of Set 4 | trindade
# Processing Record 47 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | coquimbo
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | beni suef
# Processing Record 4 of Set 5 | mosquera
# Processing Record 5 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 5 | thompson
# Processing Record 7 of Set 5 | deputatskiy
# Processing Record 8 of Set 5 | baffa
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | krasnyy chikoy
# Processing Record 11 of Set 5 | baturite
# Processing Record 12 of Set 5 | bhuj
# Processing Record 13 of Set 5 | natchez
# Processing Record 14 of Set 5 | sinnamary
# Processing Record 15 of Set 5 | lagdo
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | bandarbeyla
# Processing Record 19 of Set 5 | waitati
# Processing Record 20 of Set 5 | banjar
# Processing Record 21 of Set 5 | tigil
# Processing Record 22 of Set 5 | yulara
# Processing Record 23 of Set 5 | belaya gora
# Processing Record 24 of Set 5 | komsomolskiy
# Processing Record 25 of Set 5 | lakatoro
# Processing Record 26 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 5 | carballo
# Processing Record 28 of Set 5 | dukat
# Processing Record 29 of Set 5 | kargasok
# Processing Record 30 of Set 5 | lowestoft
# Processing Record 31 of Set 5 | baykit
# Processing Record 32 of Set 5 | innisfail
# Processing Record 33 of Set 5 | linping
# Processing Record 34 of Set 5 | gokak
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | puerto colombia
# Processing Record 38 of Set 5 | saint-philippe
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | chicama
# Processing Record 42 of Set 5 | rafraf
# Processing Record 43 of Set 5 | ust-maya
# Processing Record 44 of Set 5 | iquique
# Processing Record 45 of Set 5 | bakchar
# Processing Record 46 of Set 5 | andenes
# Processing Record 47 of Set 5 | qaqortoq
# Processing Record 48 of Set 5 | pisco
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | zhigansk
# Processing Record 1 of Set 6 | cayambe
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | ocos
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | pahrump
# Processing Record 6 of Set 6 | bronnoysund
# Processing Record 7 of Set 6 | caucaia
# Processing Record 8 of Set 6 | hammerfest
# Processing Record 9 of Set 6 | cap malheureux
# Processing Record 10 of Set 6 | sao filipe
# Processing Record 11 of Set 6 | obigarm
# Processing Record 12 of Set 6 | jistebnice
# Processing Record 13 of Set 6 | pangnirtung
# Processing Record 14 of Set 6 | kirillov
# Processing Record 15 of Set 6 | qui nhon
# Processing Record 16 of Set 6 | esperance
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | grindavik
# Processing Record 19 of Set 6 | weyburn
# Processing Record 20 of Set 6 | bhadra
# Processing Record 21 of Set 6 | atambua
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | inirida
# Processing Record 24 of Set 6 | bongaree
# Processing Record 25 of Set 6 | pavino
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | mackay
# Processing Record 28 of Set 6 | mackenzie
# Processing Record 29 of Set 6 | gimli
# Processing Record 30 of Set 6 | bolanos de calatrava
# Processing Record 31 of Set 6 | arcata
# Processing Record 32 of Set 6 | vestmanna
# Processing Record 33 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 6 | preeceville
# Processing Record 35 of Set 6 | horsham
# Processing Record 36 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | harstad
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | datong
# Processing Record 42 of Set 6 | airai
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | katherine
# Processing Record 45 of Set 6 | buala
# Processing Record 46 of Set 6 | ouadda
# Processing Record 47 of Set 6 | kenora
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | batagay-alyta
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | mus
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | chibombo
# Processing Record 6 of Set 7 | frankfort
# Processing Record 7 of Set 7 | kostomuksha
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | bethanien
# Processing Record 10 of Set 7 | praia
# Processing Record 11 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | atbasar
# Processing Record 14 of Set 7 | dryden
# Processing Record 15 of Set 7 | udachnyy
# Processing Record 16 of Set 7 | mar del plata
# Processing Record 17 of Set 7 | hovd
# Processing Record 18 of Set 7 | ayia marina
# Processing Record 19 of Set 7 | moerai
# Processing Record 20 of Set 7 | muros
# Processing Record 21 of Set 7 | konya
# Processing Record 22 of Set 7 | yate
# Processing Record 23 of Set 7 | verkhnyaya toyma
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | kathmandu
# Processing Record 26 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 7 | dong hoi
# Processing Record 28 of Set 7 | nyaunglebin
# Processing Record 29 of Set 7 | sergeyevka
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | jian
# Processing Record 32 of Set 7 | lilongwe
# Processing Record 33 of Set 7 | warrnambool

# %%
len(city_data)
# Out:
# 723

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)

weather_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Rikitea -23.1203 -134.9692     67.51        78         100
# 1       Port Alfred -33.5906   26.8910     57.94        59          47
# 2          Hermanus -34.4187   19.2345     60.91        71           0
# 3             Ukiah  39.1502 -123.2078     83.44        51           1
# 4    Port Macquarie -31.4333  152.9167     53.56        87          97
# ..              ...      ...       ...       ...       ...         ...
# 718         Serenje -13.2325   30.2352     72.01        29          14
# 719         Chegutu -18.1302   30.1407     79.25        36          40
# 720   Milledgeville  33.0801  -83.2321     82.74        73          61
# 721      Fort Dodge  42.4975  -94.1680     75.74        64          20
# 722   Benito Juarez  19.3850  -99.1650     73.74        53          75
#
#      Wind Speed Country Current Description
# 0          4.74      PF       moderate rain
# 1          6.49      ZA    scattered clouds
# 2         20.89      ZA           clear sky
# 3          3.44      US           clear sky
# 4          9.08      AU     overcast clouds
# ..          ...     ...                 ...
# 718        4.92      ZM          few clouds
# 719       16.33      ZW    scattered clouds
# 720        4.61      US       broken clouds
# 721        8.05      US          few clouds
# 722        6.91      MX       broken clouds
#
# [723 rows x 9 columns]

# %%
file_to_save = "WeatherPy_Database.csv"
weather_data_df.to_csv(file_to_save, index_label="City_ID")
